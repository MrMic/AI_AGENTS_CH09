# %%
import os

OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# Wikimedia serves a robot-policy stub unless the UA names a contact
os.environ.setdefault(
    "USER_AGENT", "ch09-question-transformations/0.1 (mic.a.elle.chlon@gmail.com)"
)

from langchain_chroma import Chroma
from langchain_community.document_loaders import AsyncHtmlLoader
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import HTMLSectionSplitter

# %%
uk_granular_collection = Chroma(
    collection_name="uk_granular",
    embedding_function=OpenAIEmbeddings(api_key=OPENAI_API_KEY),
)

uk_granular_collection.reset_collection()

uk_destinations = [
    "Cornwall",
    "North_Cornwall",
    "South_Cornwall",
    "West_Cornwall",
    "Tintagel",
    "Bodmin",
    "Wadebridge",
    "Penzance",
    "Newquay",
    "St_Ives",
    "Port_Isaac",
    "Looe",
    "Polperro",
    "Porthleven",
    "East_Sussex",
    "Brighton",
    "Battle",
    "Hastings_(England)",
    "Rye_(England)",
    "Seaford",
    "Ashdown_Forest",
]

wikivoyage_root_url = "https://en.wikivoyage.org/wiki"
uk_destination_urls = [f"{wikivoyage_root_url}/{d}" for d in uk_destinations]

headers_to_split_on = [("h1", "Header 1"), ("h2", "Header 2")]
html_section_splitter = HTMLSectionSplitter(headers_to_split_on=headers_to_split_on)

# %%
def split_docs_into_granular_chunks(docs):
    all_chunks = []
    for doc in docs:
        html_string = doc.page_content
        temp_chunks = html_section_splitter.split_text(html_string)
        h2_temp_chunks = [chunk for chunk in
                          temp_chunks if "Header 2" in chunk.metadata]
        all_chunks.extend(h2_temp_chunks)
    return all_chunks


for destination_url in uk_destination_urls:
    html_loader = AsyncHtmlLoader(destination_url)
    docs = html_loader.load()
    granular_chunks = split_docs_into_granular_chunks(docs)
    print(destination_url, len(granular_chunks), "chunks")
    if granular_chunks:
        uk_granular_collection.add_documents(documents=granular_chunks)
# Out:
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  4.84it/s]
# https://en.wikivoyage.org/wiki/Cornwall 16 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  4.00it/s]
# https://en.wikivoyage.org/wiki/North_Cornwall 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  7.37it/s]
# https://en.wikivoyage.org/wiki/South_Cornwall 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  1.12it/s]
# https://en.wikivoyage.org/wiki/West_Cornwall 11 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.93it/s]
# https://en.wikivoyage.org/wiki/Tintagel 13 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  7.09it/s]
# https://en.wikivoyage.org/wiki/Bodmin 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  4.90it/s]
# https://en.wikivoyage.org/wiki/Wadebridge 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.12it/s]
# https://en.wikivoyage.org/wiki/Penzance 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.37it/s]
# https://en.wikivoyage.org/wiki/Newquay 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  7.04it/s]
# https://en.wikivoyage.org/wiki/St_Ives 14 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  7.62it/s]
# https://en.wikivoyage.org/wiki/Port_Isaac 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  2.61it/s]
# https://en.wikivoyage.org/wiki/Looe 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  8.11it/s]
# https://en.wikivoyage.org/wiki/Polperro 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  6.18it/s]
# https://en.wikivoyage.org/wiki/Porthleven 13 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.51it/s]
# https://en.wikivoyage.org/wiki/East_Sussex 16 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.86it/s]
# https://en.wikivoyage.org/wiki/Brighton 15 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  2.32it/s]
# https://en.wikivoyage.org/wiki/Battle 11 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  1.37it/s]
# https://en.wikivoyage.org/wiki/Hastings_(England) 13 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  5.64it/s]
# https://en.wikivoyage.org/wiki/Rye_(England) 12 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  6.23it/s]
# https://en.wikivoyage.org/wiki/Seaford 13 chunks
# Fetching pages:   0%|                                                                                                                                                                    | 0/1 [00:00<?, ?it/s]
# Fetching pages: 100%|############################################################################################################################################################| 1/1 [00:00<00:00,  7.03it/s]
# https://en.wikivoyage.org/wiki/Ashdown_Forest 13 chunks

# %%
# user_question = "Tell me some fun things I can enjoy in Cornwall"
# initial_results = uk_granular_collection.similarity_search(
#     query=user_question,k=4)
# for doc in initial_results:
#     print(doc)

# %% [markdown]
# ### 9.1.2/ Setting up the query rewriter chain

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-5-nano", api_key=OPENAI_API_KEY)

# %%
rewriter_prompt_template = """
Generate search query for the ChromaDB vector store
from a user question, allowing for a more accurate
response through semantic search.
Just return the revised ChromaDB query, with quotes around it.
User question: {user_question}
Revised ChromaDB query:
"""

rewriter_prompt = ChatPromptTemplate.from_template(rewriter_prompt_template)

# %%
rewriter_chain = rewriter_prompt | llm | StrOutputParser()

# %% [markdown]
# ### 9.1.3/ Retrieving content with the rewritten query

# %%
user_question ="Tell me some fun things I can do in Cornwall"
search_query = rewriter_chain.invoke({"user_question": user_question})
print(search_query)
# Out:
# "fun activities to do in Cornwall OR things to do in Cornwall OR Cornwall attractions OR Cornwall travel ideas OR outdoor activities in Cornwall OR family-friendly activities in Cornwall OR Cornwall sightseeing recommendations"

# %%
improved_results = uk_granular_collection.similarity_search(query=search_query,k=3)

# %%
# for doc in improved_results:
#     print(doc)

# %% [markdown]
# ### 9.1.4/ Combining everything into a single RAG chain

# %%
from langchain_core.runnables import RunnablePassthrough
retriever = uk_granular_collection.as_retriever()

rag_prompt_template = """
Given a question and some context, answer the question.
If you do not know the answer, just say I do not know.

Context: {context}
Question: {question}
"""

rag_prompt = ChatPromptTemplate.from_template(rag_prompt_template)

rewrite_retrieve_read_rag_chain = (
    {
    "context": {"user_question": RunnablePassthrough()}
        | rewriter_chain | retriever,
    "question": RunnablePassthrough(),
    }
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
user_question = "Tell me some fun things I can do in Cornwall"

answer = rewrite_retrieve_read_rag_chain.invoke(user_question)
print(answer)
# Out:
# Here are some fun things to do in Cornwall based on the guide’s ideas:
#
# - Go surfing in Newquay (kit hire and surf schools available) and catch events like the Boardmasters festival or UK championships.
# - Walk parts of the South West Coast Path for stunning coastal scenery, especially around Penwith and the Lizard.
# - Cycle the Camel Trail (an 18-mile off-road route from Padstow to Wenford Bridge).
# - Visit the Eden Project near St Austell for amazing bio-domes and gardens.
# - Have a family day out at Camel Creek Adventure Park near Wadebridge.
# - Attend local festivals: Mummer’s Day in Padstow, Obby ’Oss on May Day, and St Piran’s Day celebrations.
# - Explore charming towns and beaches: Newquay, St Ives, Port Isaac, Tintagel, and Lands End.
# - Check out cultural events like the Cornish Film Festival in Newquay and the Royal Cornwall Show in June.

# %% [markdown]
# ## 9.2/ Genarating multiple queries

# %%
from langchain_classic.retrievers.multi_query import MultiQueryRetriever
from langchain_core.prompts import ChatPromptTemplate

from typing import List
from langchain_core.output_parsers import BaseOutputParser
from pydantic import BaseModel, Field

# %%
multi_query_gen_prompt_template = """
You are an AI language model assistant. Your task
is to generate five different versions of the given
user question to retrieve relevant documents from a vector
database. By generating multiple perspectives on the user
question, your goal is to help the user overcome some of
the limitations of the distance-based similarity search.
Provide these alternative questions separated by newlines.
Original question: {question}
"""

multi_query_gen_prompt = ChatPromptTemplate.from_template(multi_query_gen_prompt_template)

# %%
class LineListOutputParser(BaseOutputParser[List[str]]):
    """Parse out a question from each output line."""

    def parse(self, text: str) -> List[str]:
        lines = text.strip().split("\n")
        return list(filter(None, lines))

questions_parser = LineListOutputParser()

# %%
llm = ChatOpenAI(model="gpt-5-nano", api_key=OPENAI_API_KEY)

multi_query_gen_chain = multi_query_gen_prompt | llm | questions_parser

# %%
user_question = "Tell me some fun things I can do in Cornwall."

multiple_queries = multi_query_gen_chain.invoke(user_question)

# %%
print(multiple_queries)
# Out:
# ['What are some fun things to do in Cornwall (UK) for a weekend trip?', 'Can you recommend family-friendly activities and attractions to enjoy in Cornwall?', 'What outdoor adventures and scenic experiences should I try while visiting Cornwall?', 'Looking for budget-friendly and unique experiences in Cornwall—what would you suggest?', 'Which beaches, towns, historic sites, and activities make for a fun itinerary in Cornwall?']

# %% [markdown]
# ### 9.2.2/ Setting up a custom multi-query retriever

# %%
basic_retriever = uk_granular_collection.as_retriever()

multi_query_retriever = MultiQueryRetriever(
    retriever=basic_retriever, llm_chain=multi_query_gen_chain, parser_key="lines"
)

# %%
user_question = "Tell me some fun things I can do in Cornwall"

retrieved_docs = multi_query_retriever.invoke(user_question)
# print(retrieved_docs)

# %% [markdown]
# ### 9.2.3/ Using a standard MultiQueryRetriever instance

# %%
std_multi_query_retriever = MultiQueryRetriever.from_llm(retriever=basic_retriever, llm=llm)

user_question = " Tell me some fun things I can do in Cornwall"
retrieved_docs = std_multi_query_retriever.invoke(user_question)
# print(retrieved_docs)

# %% [markdown]
# ## 9.3/ Step-back question

# %%
# llm = ChatOpenAI(model="gpt-5", api_key=OPENAI_API_KEY)
llm = ChatOpenAI(model="gpt-5-nano", api_key=OPENAI_API_KEY)

step_back_prompt_template = """
Generate a less specific question (aka Step-back question)
for the following detailed question, so that a wider context
can be retrieved.
Detailed question: {detailed_question}
Step-back question:
"""

step_back_prompt = ChatPromptTemplate.from_template(step_back_prompt_template)

# %%
step_back_question_gen_chain = step_back_prompt | llm | StrOutputParser()

user_question = "Can you give me some tips for a trip to Brighton?"

step_back_question = step_back_question_gen_chain.invoke(user_question)
print(step_back_question)
# Out:
# What should I consider when planning a trip to Brighton?

# %%
retriever = uk_granular_collection.as_retriever()
rag_prompt_template = """
Given a question and some context, answer the question.
If you do not know the answer, just say I do not know.

Context: {context}
Question: {question}
"""

rag_prompt = ChatPromptTemplate.from_template(rag_prompt_template)
step_back_question_rag_chain = (
    {
        "context": {"detailed_question": RunnablePassthrough()}
        | step_back_question_gen_chain
        | retriever,
        "question": RunnablePassthrough(),
    }
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
user_question = "Can you give me some tips for a trip to Brighton?"

answer = step_back_question_rag_chain.invoke(user_question)
# print(answer)

# %% [markdown]
# ## 9.4/ Hypothetical Document Embeddings (HyDE)
